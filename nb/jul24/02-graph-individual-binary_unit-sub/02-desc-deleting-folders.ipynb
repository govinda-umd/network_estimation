# %%
import os
import shutil
from glob import glob

# %%
folders_to_delete = sorted(glob(
    (
        f'/home/govindas/mouse_dataset/roi_results_v2'
        f'/type-spatial_size-225_symm-True_braindiv-whl_nrois-162/graph-constructed'
        f'/method-pearson-corr/threshold-positive/edge-binary/density-20'
        f'/layer-individual/unit-sub/estimates'
        f'/individual/sub-SLC*/community-interactions'
    ),
    recursive=True
))
folders_to_delete
# Out:
# ['/home/govindas/mouse_dataset/roi_results_v2/type-spatial_size-225_symm-True_braindiv-whl_nrois-162/graph-constructed/method-pearson-corr/threshold-positive/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC01/community-interactions',
#  '/home/govindas/mouse_dataset/roi_results_v2/type-spatial_size-225_symm-True_braindiv-whl_nrois-162/graph-constructed/method-pearson-corr/threshold-positive/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC02/community-interactions',
#  '/home/govindas/mouse_dataset/roi_results_v2/type-spatial_size-225_symm-True_braindiv-whl_nrois-162/graph-constructed/method-pearson-corr/threshold-positive/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC03/community-interactions',
# ...

# %%
for folder in folders_to_delete:
    shutil.rmtree(folder)
