# %%
import os
import shutil
from glob import glob

# %%
folders_to_delete = sorted(glob(
    (
        f'/home/govindas/new_mouse_dataset/roi-results-v3'
        f'/source-spatial_space-ccfv2_braindiv-whl_nrois-162_res-200/graph-constructed'
        f'/method-pearson/threshold-signed/edge-binary/density-20'
        f'/layer-individual/unit-sub/estimates'
        f'/individual/sub-SLC*/partition-modes-group-aligned/sbm-nd-h/marginal-visuals/res-200/nii'
    ),
    recursive=True
))
folders_to_delete
# Out:
# ['/home/govindas/new_mouse_dataset/roi-results-v3/source-spatial_space-ccfv2_braindiv-whl_nrois-162_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC01/partition-modes-group-aligned/sbm-nd-h/marginal-visuals/res-200/nii',
#  '/home/govindas/new_mouse_dataset/roi-results-v3/source-spatial_space-ccfv2_braindiv-whl_nrois-162_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC03/partition-modes-group-aligned/sbm-nd-h/marginal-visuals/res-200/nii',
#  '/home/govindas/new_mouse_dataset/roi-results-v3/source-spatial_space-ccfv2_braindiv-whl_nrois-162_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/estimates/individual/sub-SLC04/partition-modes-group-aligned/sbm-nd-h/marginal-visuals/res-200/nii',
# ...

# %%
for folder in folders_to_delete:
    shutil.rmtree(folder)
