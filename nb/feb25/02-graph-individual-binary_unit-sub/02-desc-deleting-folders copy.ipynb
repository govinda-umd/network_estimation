# %%
import os
import shutil
from glob import glob

# %%
folders_to_delete = sorted(glob(
    (
        f'/home/govindas/new_mouse_dataset/roi-results-v3'
        f'/source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200/graph-constructed'
        f'/method-pearson/threshold-signed/edge-binary/density-20'
        f'/layer-individual/unit-sub/model-fits'
        f'/sub-SLC*/sbm-nd-o'
    ),
    recursive=True
))
folders_to_delete
# Out:
# ['/home/govindas/new_mouse_dataset/roi-results-v3/source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/model-fits/sub-SLC01_task-rest/sbm-nd-o',
#  '/home/govindas/new_mouse_dataset/roi-results-v3/source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/model-fits/sub-SLC03_task-rest/sbm-nd-o',
#  '/home/govindas/new_mouse_dataset/roi-results-v3/source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/model-fits/sub-SLC04_task-rest/sbm-nd-o',
#  '/home/govindas/new_mouse_dataset/roi-results-v3/source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200/graph-constructed/method-pearson/threshold-signed/edge-binary/density-20/layer-individual/unit-sub/model-fits/sub-SLC05_task-rest/sbm-nd-o',
# ...

# %%
for folder in folders_to_delete:
    shutil.rmtree(folder)
