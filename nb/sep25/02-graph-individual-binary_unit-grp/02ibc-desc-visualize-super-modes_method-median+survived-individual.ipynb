# %% [markdown]
# # Feb 10, 2026: visualize median membership of survived ROIs
# in 3D
#
# conda env: pyvista-env

# %%
import os 
import numpy as np 
import pandas as pd
import nibabel as nib
import pyvista as pv 

from glob import glob
from pathlib import Path 
import base64, io 
from PIL import Image 
import xml.etree.ElementTree as ET 

from svgutils.compose import Figure, SVG

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LinearSegmentedColormap
import colorcet as cc
import cmcrameri.cm as cmc

from itertools import chain 
import dill as pickle

from tqdm import tqdm

# ignore user warnings
import warnings
warnings.filterwarnings("ignore") #, category=UserWarning)

# %%
class ARGS():
    pass

args = ARGS()
args.SEED = 100

np.random.seed(args.SEED)

# %%
BASE_path = f'{os.environ["HOME"]}/new_mouse_dataset'
PARCELS_path = f'{BASE_path}/parcels'
os.makedirs(PARCELS_path, exist_ok=True)

# %%
args.source = 'allen'
args.space = 'ccfv2'
args.brain_div = 'whl'
args.num_rois = 172
args.resolution = 200

PARC_DESC = (
    f'source-{args.source}'
    f'_space-{args.space}'
    f'_braindiv-{args.brain_div}'
    f'_nrois-{args.num_rois}'
    f'_res-{args.resolution}'
)
PARC_DESC
# Out:
# 'source-allen_space-ccfv2_braindiv-whl_nrois-172_res-200'

# %%
TEMP_DESC = (
    f'source-allen' #f'source-{args.source}'
    f'_space-{args.space}'
    f'_res-{args.resolution}'
)
TEMP_DESC
# Out:
# 'source-allen_space-ccfv2_res-200'

# %%
args.GRAPH_DEF = f'constructed'
args.GRAPH_METHOD = f'pearson'
args.THRESHOLD = f'signed'
args.EDGE_DEF = f'binary'
args.EDGE_DENSITY = 20
args.LAYER_DEF = f'individual'
args.DATA_UNIT = f'grp'

BASE_path = f'{os.environ["HOME"]}/new_mouse_dataset'
PARCELS_path = f'{BASE_path}/parcels'
ROI_path = (
    f'{BASE_path}/roi-results-v3'
    f'/{PARC_DESC}'
)

PARCEL_VISUAL_path = f'{ROI_path}/parcellation_visuals'
os.system(f'mkdir -p {PARCEL_VISUAL_path}')

TS_path = f'{ROI_path}/roi_timeseries'
ROI_RESULTS_path = (
    f'{ROI_path}'
    f'/graph-{args.GRAPH_DEF}/method-{args.GRAPH_METHOD}'
    f'/threshold-{args.THRESHOLD}/edge-{args.EDGE_DEF}/density-{args.EDGE_DENSITY}'
    f'/layer-{args.LAYER_DEF}/unit-{args.DATA_UNIT}'
)
GRAPH_path = f'{ROI_RESULTS_path}/graphs'
os.system(f'mkdir -p {GRAPH_path}')
SBM_path = f'{ROI_RESULTS_path}/model-fits'
os.system(f'mkdir -p {SBM_path}')
DIAG_path = f'{ROI_RESULTS_path}/diagnostics'
os.system(f'mkdir -p {DIAG_path}')
ESTIM_path = f'{ROI_RESULTS_path}/estimates'
os.system(f'mkdir -p {ESTIM_path}/individual')
os.system(f'mkdir -p {ESTIM_path}/group')
# Out:
# 0

# %%
args.dc, args.sbm = False, 'h'

args.nested = True if args.sbm in ['h'] else False

args.force_niter = 100000
args.num_draws = int((1/2) * args.force_niter)

def sbm_name(args):
    dc = f'dc' if args.dc else f'nd'
    dc = f'' if args.sbm in ['m', 'a'] else dc
    file = f'sbm-{dc}-{args.sbm}'
    return file

SBM = sbm_name(args)
SBM
# Out:
# 'sbm-nd-h'

# %%
template_file = f'{PARCELS_path}/{TEMP_DESC}_desc-template.nii.gz'
# template_img = nib.load(template_file)

# %%
parcels_file = f'{PARCELS_path}/{PARC_DESC}_desc-parcels.nii.gz'
# parcels_img = nib.load(parcels_file)

try:
    roi_table = pd.read_csv(f'{PARCELS_path}/{PARC_DESC}_desc-names.csv')
    roi_labels = roi_table['roi'].to_numpy()
except:
    roi_labels = np.arange(1, args.num_rois+1)

# %%
def get_membership_matrix(num_rois, df, col='pi'):
    pis = [np.zeros((num_rois, 1)) if np.isnan(pi).all() else pi for pi in df[col]]

    num_modes = len(df)
    num_comms = np.max([pi.shape[-1] for pi in pis])
    num_rois = num_rois
    M = np.zeros((num_rois, num_modes, num_comms)) # membership profile matrix

    for idx_mode, pi in enumerate(pis):
        M[:, idx_mode, :pi.shape[-1]] = pi
    
    return M

# %%
args.method = 'hierarchical' #clustering method for finding super-modes

# %%
folder = f'{ESTIM_path}/group/multiplicity/partition/{SBM}'
os.makedirs(folder, exist_ok=True)

level = 1

with open(f'{folder}/level-{level}_desc-super-mode-median-pis.pkl', 'rb') as f:
    median_pis = pickle.load(f)

# %%
median_pis[0].shape
# Out:
# (172, 9)

# %%
# nifti volume to mesh

# %%
def pad_volume(vol, spacing, pad=(4,4,4), origin=(0,0,0), name="scalars"):
    (sx, sy, sz) = spacing
    px, py, pz = pad 
    padw = ((px, px), (py, py), (pz, pz))
    vol_p = np.pad(vol, padw, mode="constant", constant_values=0)
    ox, oy, oz = origin
    origin_p = (ox - px*sx, oy - py*sy, oz - pz*sz)
    
    g = pv.ImageData()
    g.dimensions = vol_p.shape
    g.spacing    = spacing
    g.origin     = origin_p
    g.point_data[name] = vol_p.reshape(-1, order="F")
    return g

def make_shell(grid: pv.ImageData, iso=0.5, sample_rate=2.0, smooth_iters=100, decimate=0.5):
    g = grid
    g = g.resample(sample_rate=sample_rate)
    shell = g.contour([iso], method='marching_cubes').smooth_taubin(n_iter=smooth_iters)
    if decimate is not None and 0.0 < decimate < 1.0:
        shell = shell.decimate(decimate)
    return shell

# %%
def add_RIA_axes(p: pv.Plotter):
    ax = p.add_axes(line_width=1)
    ax.SetXAxisLabelText('R')
    ax.SetYAxisLabelText('I')
    ax.SetZAxisLabelText('A')
    ax.SetTotalLength(2, 2, 2)
    return ax

# %%
def select_rois(roi_df, hemi='B'):
    if hemi == 'B':
        return roi_df
    else:
        return roi_df[roi_df['hemi'] == hemi].reset_index(drop=True)

# %%
def plot_view(p: pv.Plotter, idx, cam_args=dict(), ):
    hemi = views_df.at[idx, 'hemi']
    underlay_mesh = template_df[template_df['hemi'] == hemi]['mesh'].to_list()[0]
    roi_df = select_rois(rois_df, hemi)
    
    # add_RIA_axes(p)
    
    p.add_mesh(
        underlay_mesh,
        color='#cccccc', opacity=0.18, smooth_shading=True,
    )
    
    for idx_, row in roi_df.iterrows():
        roi, hemi, roi_mesh, color, opacity = row
        p.add_mesh(
            roi_mesh, 
            color=color,
            opacity=opacity, 
            smooth_shading=True,
        )
        
    p.camera_position = cam_args['pos']
    p.camera.roll = cam_args['roll']
    p.camera.azimuth = cam_args['a']
    p.camera.elevation = cam_args['e']
    
    return p

# %%
def single_view(idx, folder, camera_args):
    ncols = 1
    nrows = 1
    w = 20 / 9 # points
    h = w
    p = pv.Plotter(
        shape=(nrows, ncols),
        # window_size=(ncols*w, nrows*h), 
        off_screen=True, 
        border=False,
    )
    # p.enable_parallel_projection() # identical scale in every subplot
    p.set_background('white')

    camera_args['a'] = 45 * idx
    p = plot_view(p, idx, camera_args)
    
    p.save_graphic(f'{folder}/scene_{idx}.svg')
    p.export_html(f'{folder}/scene.html')

# %%
# cropping + tightening images

# %%
# chatgpt gave this cell
SVG_NS = 'http://www.w3.org/2000/svg'
XLINK_NS = 'http://www.w3.org/1999/xlink'
ET.register_namespace('', SVG_NS)
ET.register_namespace('xlink', XLINK_NS)

def _get_image_elem(root):
    # Return the first  element
    return root.find(f".//{{{SVG_NS}}}image")

def _load_rgba_from_href(svg_path, href):
    if href.startswith("data:image"):
        b64 = href.split(",", 1)[1]
        return Image.open(io.BytesIO(base64.b64decode(b64))).convert("RGBA")
    # relative/absolute file path
    p = Path(href)
    if not p.exists():
        p = (Path(svg_path).parent / href).resolve()
    return Image.open(p).convert("RGBA")

def _crop_white(im, white_threshold=245, pad_px=0):
    a = np.array(im)
    rgb, alpha = a[..., :3], a[..., 3]
    near_white = (rgb >= white_threshold).all(axis=-1)
    a[..., 3] = np.where(near_white, 0, alpha)   # make near-white transparent
    alpha2 = a[..., 3]
    ys, xs = np.where(alpha2 > 0)
    if xs.size == 0:  # nothing found: return original
        return Image.fromarray(a, "RGBA")
    x0, x1 = max(0, xs.min()-pad_px), min(im.width,  xs.max()+1+pad_px)
    y0, y1 = max(0, ys.min()-pad_px), min(im.height, ys.max()+1+pad_px)
    return Image.fromarray(a, "RGBA").crop((x0, y0, x1, y1))

def _write_tight_svg(out_path, pil_rgba):
    buf = io.BytesIO()
    pil_rgba.save(buf, format="PNG")
    data_uri = "data:image/png;base64," + base64.b64encode(buf.getvalue()).decode("ascii")
    svg = ET.Element(f"{{{SVG_NS}}}svg", {
        "version":"1.1",
        "width":  f"{pil_rgba.width}px",
        "height": f"{pil_rgba.height}px",
        "viewBox": f"0 0 {pil_rgba.width} {pil_rgba.height}",
    })
    ET.SubElement(svg, f"{{{SVG_NS}}}image", {
        f"{{{XLINK_NS}}}href": data_uri,
        "x":"0", "y":"0",
        "width": str(pil_rgba.width),
        "height":str(pil_rgba.height),
        "preserveAspectRatio":"none",
    })
    ET.ElementTree(svg).write(out_path, encoding="utf-8", xml_declaration=True)
    
def trim_svg(svg_in, svg_out=None, white_threshold=245, pad_px=0):
    """Read SVG, crop embedded raster to remove white margins, write tight SVG."""
    svg_in = Path(svg_in)
    if svg_out is None:
        svg_out = svg_in.with_suffix("").with_name(svg_in.stem + "_cropped").with_suffix(".svg")
    root = ET.parse(svg_in).getroot()
    img = _get_image_elem(root)
    if img is None:
        raise RuntimeError("No  element found (this expects an SVG that wraps a raster).")
    href = img.get(f"{{{XLINK_NS}}}href") or img.get("href")
    if not href:
        raise RuntimeError("No href on  (neither xlink:href nor href).")
    im = _load_rgba_from_href(svg_in, href)
    cropped = _crop_white(im, white_threshold=white_threshold, pad_px=pad_px)
    _write_tight_svg(svg_out, cropped)
    return str(svg_out), (cropped.width, cropped.height)

# %%
# montage individual views

# %%
def montage_scenes(folder, sizes):
    slots = [(1,2), (2,2), (2,1), (2,0), (1,0), (0,0), (0,1), (0,2)]
    
    Ws = np.zeros((3, 3))
    Hs = np.zeros((3, 3))

    for idx in range(8):
        w, h = sizes[idx]
        r, c = slots[idx]
        Ws[r, c] = w 
        Hs[r, c] = h

    # total size of image
    W = np.sum(Ws, axis=1).max() # total width of image
    H = np.sum(Hs, axis=0).max() # total height of image
    
    # positions of each panel
    Xs = np.zeros((3, 3))
    for i in range(3):
        Xs[i,0] = 0
        Xs[i,1] = Ws[i,0]
        Xs[i,2] = W - Ws[i,2]

    Ys = np.zeros((3, 3))
    for j in range(3):
        Ys[0,j] = 0
        Ys[1,j] = Hs[0,j]
        Ys[2,j] = H - Hs[2,j]
        
    elems = [SVG(f'{folder}/scene_{i}_cropped.svg').move(Xs[r,c], Ys[r,c])
            for i,(r,c) in enumerate(slots)]
    Figure(f"{W}px", f"{H}px", *elems).save(f'{folder}/montage.svg')

# %%
# finally main script :)

# %%
pad_vox = (4, 4, 4) # padding to avoid open ends (olfactory/cerebellum)

# %%
img = nib.load(template_file)
template_vol = img.get_fdata()[::-1, :, :]
spacing = img.header.get_zooms()[:3]
template_grid = pad_volume(
    template_vol, 
    spacing, pad=pad_vox, 
    origin=(0, 0, 0), name='template'
)
template_mesh = make_shell(
    template_grid, 
    iso=30, sample_rate=1, 
    smooth_iters=75
)

# %%
x0 = 0.5*(template_mesh.bounds[0] + template_mesh.bounds[1])
y0 = 0.5*(template_mesh.bounds[2] + template_mesh.bounds[3])
z0 = 0.5*(template_mesh.bounds[4] + template_mesh.bounds[5])
MID_ORIGIN = (x0, y0, z0)

right_temp_mesh = template_mesh.clip(normal=(-1,0,0), origin=MID_ORIGIN).triangulate().clean()  # keeps x >= x0
left_temp_mesh = template_mesh.clip(normal=( 1,0,0), origin=MID_ORIGIN).triangulate().clean()  # keeps x <= x0
right_temp_mesh = right_temp_mesh.fill_holes(50).clean()
left_temp_mesh = left_temp_mesh.fill_holes(50).clean()

# %%
template_df = pd.DataFrame(dict(
    hemi=['L', 'R', 'B'],
    mesh=[left_temp_mesh, right_temp_mesh, template_mesh],
))
template_df
# Out:
#   hemi                                               mesh
# 0    L  PolyData (0x7ffac2bc11e0)\n  N Cells:    12307...
# 1    R  PolyData (0x7ffac2bc1360)\n  N Cells:    12383...
# 2    B  PolyData (0x7ffac2bc1420)\n  N Cells:    22518...

# %%
camera_args = dict(
    pos='yz',
    roll=180,
    a=0, # update azimuth here for each view
    e=35,
)

views_df = pd.DataFrame(dict(
    idx=[0, 1, 2, 3, 4, 5, 6, 7],
    hemi=['L', 'B', 'B', 'B', 'R', 'B', 'B', 'B']
))
views_df
# Out:
#    idx hemi
# 0    0    L
# 1    1    B
# 2    2    B
# 3    3    B
# 4    4    R
# 5    5    B
# 6    6    B
# 7    7    B

# %%
parcels_img = nib.load(parcels_file)
parcels_vol = parcels_img.get_fdata()[::-1, :, :]
spacing = parcels_img.header.get_zooms()[:3]

# %%
def get_rois_df(args, comm, roi_vector, roi_labels, parcels_vol, cmap, norm):
    rois_df = []
    for idx_roi, (roi_label, membership) in enumerate(zip(roi_labels, roi_vector)):
        if abs(membership) < args.thresh: continue
        roi_vol = (parcels_vol == roi_label).astype(int)
        roi_grid = pad_volume(roi_vol, spacing, pad=pad_vox, origin=(0, 0, 0), name=f'roi-{roi_label:03d}')
        roi_mesh = make_shell(roi_grid, sample_rate=1, smooth_iters=150)
        row = {
            'roi': roi_label,
            'hemi': 'R' if roi_label <= args.num_rois / 2 else 'L',
            'mesh': roi_mesh,
            'color': cmap(norm(membership))[:3],
            'opacity': min(np.power(abs(membership), args.power), 1), # powerlaw opacity to fade away low prob ROIs.
        }
        rois_df += [row]
    rois_df = pd.DataFrame(rois_df)#.sort_values('roi').reset_index(drop=True)
    return rois_df

# %%
level = 1

# %%
def create_sequential_cmap(target_color='#000000', background_color='#cccccc'):
    """
    Creates a sequential map from Background -> Target.
    Perfect for blending low-value ROIs into the mesh.
    """
    # Simply interpolate from Background to Target
    colors = [background_color, target_color]
    cmap_name = f'blend_to_{target_color}'
    return LinearSegmentedColormap.from_list(cmap_name, colors, N=256)

# %%
args.thresh = 0.1
args.power = 1.0

norm_mean = Normalize(vmin=0, vmax=1)
args.cmap_mean = cmc.batlow #create_sequential_cmap('#1a1a1a') #plt.cm.viridis #mpl.cm.Blues # cc.cm.CET_L12 #cmc.batlow #

gradient = np.linspace(0, 1, 256).reshape(1, -1)
rgba_colors = args.cmap_mean(gradient)
dist_from_center = np.abs(gradient - 0.0) * 2
rgba_colors[:, :, 3] = np.power(dist_from_center, args.power)
cmap_fig, ax = plt.subplots(figsize=(4, 0.75))
ax.imshow(rgba_colors.reshape(1, 256, 4), aspect='auto')
ax.set_axis_off()
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..2.0].

# %%
for mode_idx, pi in enumerate(median_pis): 

    main_out_folder = (
        f'{ESTIM_path}/group/multiplicity/partition/{SBM}'
        f'/median-super-modes-visuals/level-{level}/method-{args.method}'
        f'/mode-{mode_idx+1:02d}'
    )
    os.makedirs(main_out_folder, exist_ok=True)

    cmap_fig.savefig(f'{main_out_folder}/colormap.svg', bbox_inches='tight', transparent=True)

    for idx_comm in range(pi.shape[1]):
        out_folder = (
            f'{main_out_folder}/comm-{idx_comm+1:02d}'
        )
        os.makedirs(out_folder, exist_ok=True)
        
        roi_vector = pi[:, idx_comm]
        rois_df = get_rois_df(args, idx_comm, roi_vector, roi_labels, parcels_vol, args.cmap_mean, norm_mean)
        
        try:
            # render 3d views
            for _, view_row in views_df.iterrows():
                idx = view_row['idx']
                single_view(idx, out_folder, camera_args)
                
            pad = 10 #px
            sizes = []
            for svg_in in sorted(glob(f'{out_folder}/scene_?.svg')):
                svg_out, size = trim_svg(svg_in)
                sizes += [(size[0]+pad, size[1]+pad)]
            # print(sizes)
            montage_scenes(out_folder, sizes)
        except: 
            pass

    # break
# Out:
# 2026-02-18 17:24:06.468 (   9.798s) [    7FFBB292A740]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:06.595 (   9.925s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35bee9b10): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:06.784 (  10.114s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35c476700): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:07.015 (  10.345s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35bee9b10): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:08.889 (  12.219s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35fb845f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:08.901 (  12.231s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f360b3bb60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:08.961 (  12.291s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35fb845f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:09.558 (  12.888s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3627a4e40): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:09.563 (  12.893s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36279c520): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:09.601 (  12.931s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3627a4e40): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.149 (  13.479s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36279c520): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.154 (  13.484s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f360b2f7a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.192 (  13.522s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36279c520): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.862 (  14.192s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36775a740): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.866 (  14.196s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f367785990): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:10.894 (  14.224s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36775a740): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.310 (  14.640s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35fd5dfc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.315 (  14.645s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f367369f60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.365 (  14.695s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f35fd5dfc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.899 (  15.229s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f367369f60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.903 (  15.233s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36cf7f170): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:11.942 (  15.272s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f367369f60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:12.603 (  15.933s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36f534290): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:12.609 (  15.939s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36f5905c0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:12.648 (  15.978s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f36f534290): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:13.794 (  17.124s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f371823470): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:13.798 (  17.129s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3700fd890): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:13.843 (  17.173s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f371823470): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:14.317 (  17.647s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f370120ff0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:14.322 (  17.652s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3700fd890): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:14.380 (  17.710s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f370120ff0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:14.980 (  18.310s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f371bfbe90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:14.985 (  18.315s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f375eee1d0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:15.036 (  18.366s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3768f8420): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:15.721 (  19.051s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f371bfbe90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:15.725 (  19.055s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3700fd890): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:15.775 (  19.105s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f371bfbe90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.342 (  19.672s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3700fd890): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.348 (  19.678s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37b34f0c0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.374 (  19.704s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3700fd890): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.824 (  20.154s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37e35b930): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.829 (  20.159s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37660ac40): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:16.879 (  20.209s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37e35b930): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:17.576 (  20.906s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37e183c30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:17.580 (  20.910s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37660ac40): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:17.630 (  20.960s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f37e183c30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:18.219 (  21.550s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f380be3280): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:18.224 (  21.554s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f380be3280): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:18.276 (  21.606s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f380da1700): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.509 (  22.839s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38571bb70): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.514 (  22.844s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3851237f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.537 (  22.868s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38571bb70): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.927 (  23.257s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3850bf290): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.933 (  23.263s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f385dd31e0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:19.971 (  23.301s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3850bf290): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:20.470 (  23.800s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f385dd31e0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:20.475 (  23.805s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38a56e860): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:20.505 (  23.836s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f385dd31e0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:20.991 (  24.322s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f385d2b480): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:20.997 (  24.327s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38c50c7d0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.028 (  24.358s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38abef5d0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.563 (  24.893s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38ed09030): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.568 (  24.898s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38edca870): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.589 (  24.920s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38ed09030): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.983 (  25.313s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3912c5000): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:21.988 (  25.319s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38a52edf0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:22.019 (  25.349s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3912c5000): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:22.512 (  25.843s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38c8dcb80): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:22.518 (  25.848s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f393b0cb50): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:22.549 (  25.879s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f38c8dcb80): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:23.093 (  26.423s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3910e2e00): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:23.099 (  26.429s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f396120710): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:23.129 (  26.460s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3910e2e00): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.183 (  27.513s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3984672f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.187 (  27.517s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39843d610): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.244 (  27.574s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3984672f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.803 (  28.133s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3982babc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.808 (  28.138s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39872d410): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:24.861 (  28.191s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3982babc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:25.403 (  28.733s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39d86ff10): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:25.408 (  28.738s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39843d610): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:25.450 (  28.780s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39d86ff10): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:25.994 (  29.324s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a0240520): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:25.999 (  29.329s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39fecad90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:26.043 (  29.373s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a0240520): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:26.594 (  29.925s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39872d410): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:26.600 (  29.930s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a2a8acf0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:26.629 (  29.959s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39872d410): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.089 (  30.419s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a4c56620): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.094 (  30.424s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a2a8acf0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.138 (  30.468s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a277d8f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.686 (  31.016s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a4c56620): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.692 (  31.022s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a2a8acf0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:27.735 (  31.065s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a4c56620): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:28.458 (  31.788s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39843d610): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:28.464 (  31.794s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3a938af00): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:28.508 (  31.838s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f39843d610): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:29.564 (  32.894s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f398742910): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:29.569 (  32.899s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3ac1e2c00): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:29.595 (  32.925s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f398742910): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:30.019 (  33.349s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3acdd96a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:24:30.024 (  33.354s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f3abc42280): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# ...
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:43.959 ( 347.289s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c0f81f00): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:44.568 ( 347.898s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c657fb50): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:44.574 ( 347.904s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c5d86b30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:44.641 ( 347.971s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c657fb50): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:45.513 ( 348.843s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c5d86b30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:45.519 ( 348.849s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c9fa00a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:45.587 ( 348.917s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c5d86b30): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:46.449 ( 349.779s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cb2e71a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:46.454 ( 349.784s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cb0ec720): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:46.522 ( 349.852s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cb2e71a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.063 ( 351.393s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cc8134c0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.068 ( 351.398s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6c9fa00a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.119 ( 351.449s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cc8134c0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.611 ( 351.941s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d1f63690): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.616 ( 351.946s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cfe70f90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:48.695 ( 352.025s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d1f63690): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:49.400 ( 352.730s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d2630dc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:49.406 ( 352.736s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cfea2f60): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:49.448 ( 352.778s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d2630dc0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.105 ( 353.436s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cfe70f90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.111 ( 353.441s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d78567f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.153 ( 353.483s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6cfe70f90): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.836 ( 354.166s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d5b0e110): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.841 ( 354.171s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d78567f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:50.871 ( 354.201s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d5b0e110): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:51.350 ( 354.680s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6db86e9f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:51.355 ( 354.685s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6db86e9f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:51.396 ( 354.726s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d7c1f220): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.081 ( 355.411s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6dc198e50): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.086 ( 355.416s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6de5676a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.128 ( 355.458s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6dc198e50): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.857 ( 356.187s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6de5676a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.862 ( 356.192s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6d78567f0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD129: Permission denied
#
# libEGL warning: failed to open /dev/dri/card1: Permission denied
#
# 2026-02-18 17:29:52.905 ( 356.235s) [    7FFBB292A740] vtkEGLRenderWindow.cxx:359   WARN| vtkEGLRenderWindow (0x55f6de5676a0): EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/card0: Permission denied
